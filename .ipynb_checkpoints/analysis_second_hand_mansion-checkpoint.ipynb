# %%
import pandas as pd
import xgboost as xgb
import category_encoders as ce
from sklearn.model_selection import train_test_split

# %%
sample_submission = pd.read_csv(r"data/sample_submission.csv")
# 提出用ファイルの中身の確認
sample_submission
# Out:
#              ID  取引価格（総額）_log
# 0       1000000             0
# 1       1000001             0
# 2       1000062             0
# 3       1000114             0
# 4       1000116             0
# ...         ...           ...
# 23146  47006024             0
# 23147  47006082             0
# 23148  47006216             0
# 23149  47006238             0
# 23150  47006240             0
#
# [23151 rows x 2 columns]

# %%
#input file name
input_file_name = 'data/data_explanation.xlsx'
#xls book Open (xls, xlsxのどちらでも可能)
input_book = pd.ExcelFile(input_file_name)
#sheet_namesメソッドでExcelブック内の各シートの名前をリストで取得できる
input_sheet_name = input_book.sheet_names
#lenでシートの総数を確認
num_sheet = len(input_sheet_name)
#シートの数とシートの名前のリストの表示
print ("Sheet の数:", num_sheet)
print (input_sheet_name)
# Out:
# Sheet の数: 2
# ['ファイル説明', 'カラム説明']

# %%
#DataFrameとしてsheet1枚のデータ(ファイル説明)を読込み
input_sheet_df = input_book.parse(input_sheet_name[0])
#読み込んだシート名の確認
print("Sheet name:", input_sheet_name[0])
#読み込んだシートの先頭10行を表示
input_sheet_df[['ファイル名', '内容']].head()
# Out:
# Sheet name: ファイル説明
#                    ファイル名                                        内容
# 0    train.zip\n └─*.csv          2020年第４四半期より前に取引された中古マンションの価格データ
# 1               test.csv  2020年第４四半期、2021年第１四半期に取引された中古マンションの価格データ
# 2  sample_submission.csv                               投稿データフォーマット

# %%
#DataFrameとしてsheet1枚のデータ(ファイル説明)を読込み
input_sheet_df = input_book.parse(input_sheet_name[1])
#読み込んだシート名の確認
print("Sheet name:", input_sheet_name[1])
# Out:
# Sheet name: カラム説明

# %%
#読み込んだシートの先頭10行を表示
columns_list = input_sheet_df.columns
input_sheet_df[['{}'.format(columns_list[0]), '{}'.format(columns_list[1])]]
# Out:
#             カラム名                                                 内容
# 0             ID                                               取引ID
# 1             種類                                             不動産の種類
# 2             地域                                周辺地域の状況　※本データではnull
# 3        市区町村コード                                            市区町村コード
# 4          都道府県名                                              都道府県名
# 5          市区町村名                                              市区町村名
# 6            地区名                                                地区名
# 7         最寄駅：名称                                         最寄りの鉄道駅の名称
# 8      最寄駅：距離（分）            当該地から最寄りの鉄道駅（地下駅の場合には地表への出入口）までの時間距離（分）
# 9            間取り  専有部分の間取りを表示しています。なお、間取りが把握できないものは、空欄になっています。\n...
# 10         面積（㎡）  登記簿に記載されている専有部分の床面積(㎡)（壁その他の区画の内側で測定（内定）された面積）...
# 11         土地の形状  土地のおおよその形状を「正方形」、「ほぼ正方形」、「長方形」、「ほぼ長方形」、「台形」、「ほ...
# 12            間口               土地の接道幅（m）（土地が道路に接している長さ）　※本データではnull
# 13       延床面積（㎡）                                延床面積(㎡)　※本データではnull
# 14           建築年  当該建物の建築年を表示しています。\nなお、1945年以前は「戦前」と表示されます。また、建...
# 15         建物の構造  当該建物の構造を次の略号で表示しています。\nなお、構造が把握できないものは、空欄になってい...
# 16            用途  利用の現況を表示しています。\nなお、複合用途の場合は列記しています。また、用途が把握できな...
# 17       今後の利用目的  今後予定されている利用目的を表示しています。\nなお、利用目的が把握できないものは、空欄にな...
# 18       前面道路：方位      土地が接面する前面道路の方位。\nなお、前面道路が把握できないものは、空欄になっています。
# 19       前面道路：種類  土地が接面する前面道路の種類。\nなお、前面道路が把握できないものは、空欄になっています。\...
# 20    前面道路：幅員（ｍ）   土地が接面する前面道路の幅員（ｍ）。\nなお、前面道路が把握できないものは、空欄になっています。
# 21          都市計画  都市計画法上の用途地域などを次の略号で表示しています。\nなお、都市計画が把握できないものは...
# 22       建ぺい率（％）                     指定建ぺい率（％）。把握できないものは、空欄になっています。
# 23        容積率（％）                      指定容積率（％）。把握できないものは、空欄になっています。
# 24          取引時点  取引当事者への調査により得られた売買契約日を、また、売買契約日が不詳の場合には登記簿に記載さ...
# 25            改装  改装状況を表示しています。 改装したものは「改装済」、改装していないものは「未改装」を表示し...
# 26        取引の事情等  取引にあたって価格に影響があると思われる追加情報を表示しています。アンケート調査の結果、追加...
# 27  取引価格（総額）_log        取引の総額（円）の常用対数。\n取引の総額（円）は、仲介手数料等の諸費用は含みません。

# %%
test_df = pd.read_csv('data/test.csv')
print(test_df.head())
print('columns:{}'.format(test_df.columns))
# Out:
#         ID        種類  地域  市区町村コード 都道府県名   市区町村名  地区名 最寄駅：名称 最寄駅：距離（分）   間取り  \
# 0  1000000  中古マンション等 NaN     1101   北海道  札幌市中央区  旭ケ丘   円山公園        25  ４ＬＤＫ
# 1  1000001  中古マンション等 NaN     1101   北海道  札幌市中央区  旭ケ丘   円山公園        20  ４ＬＤＫ
# 2  1000062  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１１丁目         3  ２ＬＤＫ
# 3  1000114  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１８丁目         2  １ＬＤＫ
# 4  1000116  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１８丁目         4  ２ＬＤＫ
#
#    ... 今後の利用目的  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）         都市計画 建ぺい率（％） 容積率（％）  \
# 0  ...      住宅      NaN      NaN         NaN  第１種低層住居専用地域    40.0   80.0
# 1  ...      住宅      NaN      NaN         NaN       近隣商業地域    80.0  200.0
# 2  ...      住宅      NaN      NaN         NaN         商業地域    80.0  600.0
# 3  ...      住宅      NaN      NaN         NaN         商業地域    80.0  400.0
# 4  ...      住宅      NaN      NaN         NaN       近隣商業地域    80.0  300.0
#
#          取引時点   改装  取引の事情等
# 0  2021年第１四半期  未改装     NaN
# 1  2021年第１四半期  未改装     NaN
# 2  2021年第１四半期  未改装     NaN
# 3  2021年第１四半期  未改装     NaN
# 4  2021年第１四半期  未改装     NaN
#
# [5 rows x 27 columns]
# columns:Index(['ID', '種類', '地域', '市区町村コード', '都道府県名', '市区町村名', '地区名', '最寄駅：名称',
#        '最寄駅：距離（分）', '間取り', '面積（㎡）', '土地の形状', '間口', '延床面積（㎡）', '建築年', '建物の構造',
#        '用途', '今後の利用目的', '前面道路：方位', '前面道路：種類', '前面道路：幅員（ｍ）', '都市計画', '建ぺい率（％）',
#        '容積率（％）', '取引時点', '改装', '取引の事情等'],
#       dtype='object')

# %%
import glob
train_files = glob.glob('data/train/*.csv')
print(train_files)
# Out:
# ['data/train/40.csv', 'data/train/41.csv', 'data/train/43.csv', 'data/train/42.csv', 'data/train/46.csv', 'data/train/47.csv', 'data/train/45.csv', 'data/train/44.csv', 'data/train/37.csv', 'data/train/23.csv', 'data/train/22.csv', 'data/train/36.csv', 'data/train/08.csv', 'data/train/20.csv', 'data/train/34.csv', 'data/train/35.csv', 'data/train/21.csv', 'data/train/09.csv', 'data/train/25.csv', 'data/train/31.csv', 'data/train/19.csv', 'data/train/18.csv', 'data/train/30.csv', 'data/train/24.csv', 'data/train/32.csv', 'data/train/26.csv', 'data/train/27.csv', 'data/train/33.csv', 'data/train/16.csv', 'data/train/02.csv', 'data/train/03.csv', 'data/train/17.csv', 'data/train/29.csv', 'data/train/01.csv', 'data/train/15.csv', 'data/train/14.csv', 'data/train/28.csv', 'data/train/04.csv', 'data/train/10.csv', 'data/train/38.csv', 'data/train/39.csv', 'data/train/11.csv', 'data/train/05.csv', 'data/train/13.csv', 'data/train/07.csv', 'data/train/06.csv', 'data/train/12.csv']

# %%
train_df_list = []
for file in train_files:
    df = pd.read_csv(file)
    train_df_list.append(df)
train_df = pd.concat(train_df_list)
# Out:
# /Users/masato/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print('train_df:\n{}'.format(train_df.columns))
print('test_df:\n{}'.format(test_df.columns))
print('sample_df:\n{}'.format(sample_submission.columns))
# Out:
# train_df:
# Index(['ID', '種類', '地域', '市区町村コード', '都道府県名', '市区町村名', '地区名', '最寄駅：名称',
#        '最寄駅：距離（分）', '間取り', '面積（㎡）', '土地の形状', '間口', '延床面積（㎡）', '建築年', '建物の構造',
#        '用途', '今後の利用目的', '前面道路：方位', '前面道路：種類', '前面道路：幅員（ｍ）', '都市計画', '建ぺい率（％）',
#        '容積率（％）', '取引時点', '改装', '取引の事情等', '取引価格（総額）_log'],
#       dtype='object')
# test_df:
# Index(['ID', '種類', '地域', '市区町村コード', '都道府県名', '市区町村名', '地区名', '最寄駅：名称',
#        '最寄駅：距離（分）', '間取り', '面積（㎡）', '土地の形状', '間口', '延床面積（㎡）', '建築年', '建物の構造',
#        '用途', '今後の利用目的', '前面道路：方位', '前面道路：種類', '前面道路：幅員（ｍ）', '都市計画', '建ぺい率（％）',
#        '容積率（％）', '取引時点', '改装', '取引の事情等'],
#       dtype='object')
# sample_df:
# Index(['ID', '取引価格（総額）_log'], dtype='object')

# %%
train_df['test'] = 0
test_df['test'] = 1
df = pd.concat([train_df, test_df])

# %%
def data_pre(df):
    nonnull_list = []
    for col in df.columns:
        nonnull = df[col].count()
        if nonnull == 0:
            nonnull_list.append(col)
    df = df.drop(nonnull_list, axis=1)

    df = df.drop("市区町村名", axis=1)

    df = df.drop("種類", axis=1)

    dis = {
        "30分?60分":45,
        "1H?1H30":75,
        "2H?":120,
        "1H30?2H":105
    }
    df["最寄駅：距離（分）"] = df["最寄駅：距離（分）"].replace(dis).astype(float)

    df["面積（㎡）"] = df["面積（㎡）"].replace("2000㎡以上", 2000).astype(float)


    y_list = {}
    for i in df["建築年"].value_counts().keys():
        if "平成" in i:
            num = float(i.split("平成")[-1].split("年")[0])
            year = 33 - num
        if "令和" in i:
            num = float(i.split("令和")[-1].split("年")[0])
            year = 3 - num
        if "昭和" in i:
            num = float(i.split("昭和")[-1].split("年")[0])
            year = 96 - num
        y_list[i] = year
    y_list["戦前"] = 76
    df["建築年"] = df["建築年"].replace(y_list)

    year = {
        "年第１四半期": ".25",
        "年第２四半期": ".50",
        "年第３四半期": ".75",
        "年第４四半期": ".99"
    }
    year_list = {}
    for i in df["取引時点"].value_counts().keys():
        for k, j in year.items():
            if k in i:
                year_rep = i.replace(k, j)
        year_list[i] = year_rep
    df["取引時点"] = df["取引時点"].replace(year_list).astype(float)
    
    cols = ["都道府県名", "地区名", "最寄駅：名称", "間取り", "建物の構造", "用途", "今後の利用目的", "都市計画", "改装", "取引の事情等"]
    ce_df = ce.OrdinalEncoder(cols=cols, handle_unknown='impute')
    df = ce_df.fit_transform(df)
    
    return df
    
df = data_pre(df)
train_df = df[df['test'] == 0]
test_df = df[df['test'] == 1]

# %%
train_df = train_df.drop("test", axis = 1)
test_df = test_df.drop(["test", "取引価格（総額）_log"], axis = 1)
train_df.head()
# Out:
#          ID  市区町村コード  都道府県名  地区名  最寄駅：名称  最寄駅：距離（分）  間取り  面積（㎡）   建築年  建物の構造  \
# 0  40012297    40131      1    1       1        6.0    1   60.0  25.0      1
# 1  40067189    40133      1    2       2        4.0    2   25.0   8.0      1
# 2  40019754    40133      1    3       3        3.0    3   65.0   5.0      1
# 3  40097300    40132      1    4       4       16.0    4   15.0  26.0      1
# 4  40017646    40133      1    5       5        8.0    2   60.0  17.0      1
#
#    用途  今後の利用目的  都市計画  建ぺい率（％）  容積率（％）     取引時点  改装  取引の事情等  取引価格（総額）_log
# 0   1        1     1      NaN     NaN  2017.25   1       1      6.919078
# 1   1        2     2     80.0   400.0  2014.75   1       1      7.230449
# 2   2        1     2     80.0   400.0  2019.75   1       1      7.643453
# 3   1        2     3     80.0   300.0  2013.75   1       1      6.544068
# 4   1        1     2     80.0   400.0  2016.25   1       1      7.462398

# %%
df_train, df_val =train_test_split(train_df, test_size=0.2)

col = "取引価格（総額）_log"
train_y = df_train[col]
train_x = df_train.drop(col, axis=1)

val_y = df_val[col]
val_x = df_val.drop(col, axis=1)

train_data = xgb.DMatrix(train_x, label=train_y)
eval_data = xgb.DMatrix(val_x, label=val_y)

xgb_params = {
    "objective": "reg:squarederror",
    'eval_metric': "mae"
    }
evals = [(train_data, 'train'), (eval_data, 'eval')]

gbm = xgb.train(
    xgb_params,
    train_data,
    num_boost_round=100,
    early_stopping_rounds=10,
    evals=evals,
    )
# Out:
# [0]	train-mae:4.70601	eval-mae:4.70481
# [1]	train-mae:3.29440	eval-mae:3.29325
# [2]	train-mae:2.30629	eval-mae:2.30511
# [3]	train-mae:1.61463	eval-mae:1.61349
# [4]	train-mae:1.13089	eval-mae:1.12973
# [5]	train-mae:0.79398	eval-mae:0.79283
# [6]	train-mae:0.55998	eval-mae:0.55889
# [7]	train-mae:0.39862	eval-mae:0.39774
# [8]	train-mae:0.28992	eval-mae:0.28929
# [9]	train-mae:0.21918	eval-mae:0.21881
# [10]	train-mae:0.17453	eval-mae:0.17427
# [11]	train-mae:0.14811	eval-mae:0.14796
# [12]	train-mae:0.13278	eval-mae:0.13277
# [13]	train-mae:0.12411	eval-mae:0.12424
# [14]	train-mae:0.11897	eval-mae:0.11922
# [15]	train-mae:0.11505	eval-mae:0.11538
# [16]	train-mae:0.11299	eval-mae:0.11339
# [17]	train-mae:0.11184	eval-mae:0.11232
# [18]	train-mae:0.11084	eval-mae:0.11139
# [19]	train-mae:0.10977	eval-mae:0.11035
# [20]	train-mae:0.10886	eval-mae:0.10948
# [21]	train-mae:0.10788	eval-mae:0.10855
# [22]	train-mae:0.10728	eval-mae:0.10799
# [23]	train-mae:0.10669	eval-mae:0.10743
# [24]	train-mae:0.10531	eval-mae:0.10607
# [25]	train-mae:0.10496	eval-mae:0.10573
# [26]	train-mae:0.10457	eval-mae:0.10534
# [27]	train-mae:0.10418	eval-mae:0.10498
# [28]	train-mae:0.10358	eval-mae:0.10443
# [29]	train-mae:0.10310	eval-mae:0.10396
# [30]	train-mae:0.10249	eval-mae:0.10337
# [31]	train-mae:0.10215	eval-mae:0.10305
# [32]	train-mae:0.10183	eval-mae:0.10276
# [33]	train-mae:0.10156	eval-mae:0.10251
# [34]	train-mae:0.10136	eval-mae:0.10232
# [35]	train-mae:0.10080	eval-mae:0.10177
# [36]	train-mae:0.09992	eval-mae:0.10090
# [37]	train-mae:0.09970	eval-mae:0.10070
# [38]	train-mae:0.09903	eval-mae:0.10006
# [39]	train-mae:0.09888	eval-mae:0.09992
# [40]	train-mae:0.09879	eval-mae:0.09982
# [41]	train-mae:0.09856	eval-mae:0.09961
# [42]	train-mae:0.09800	eval-mae:0.09907
# [43]	train-mae:0.09781	eval-mae:0.09890
# [44]	train-mae:0.09764	eval-mae:0.09875
# [45]	train-mae:0.09724	eval-mae:0.09837
# [46]	train-mae:0.09695	eval-mae:0.09809
# [47]	train-mae:0.09685	eval-mae:0.09801
# [48]	train-mae:0.09660	eval-mae:0.09777
# [49]	train-mae:0.09632	eval-mae:0.09753
# [50]	train-mae:0.09619	eval-mae:0.09742
# [51]	train-mae:0.09591	eval-mae:0.09714
# [52]	train-mae:0.09582	eval-mae:0.09706
# [53]	train-mae:0.09566	eval-mae:0.09692
# [54]	train-mae:0.09541	eval-mae:0.09669
# [55]	train-mae:0.09536	eval-mae:0.09666
# [56]	train-mae:0.09506	eval-mae:0.09638
# [57]	train-mae:0.09464	eval-mae:0.09597
# [58]	train-mae:0.09441	eval-mae:0.09577
# [59]	train-mae:0.09438	eval-mae:0.09573
# [60]	train-mae:0.09404	eval-mae:0.09541
# [61]	train-mae:0.09397	eval-mae:0.09536
# [62]	train-mae:0.09372	eval-mae:0.09512
# [63]	train-mae:0.09358	eval-mae:0.09500
# [64]	train-mae:0.09352	eval-mae:0.09495
# [65]	train-mae:0.09309	eval-mae:0.09451
# [66]	train-mae:0.09295	eval-mae:0.09439
# [67]	train-mae:0.09286	eval-mae:0.09432
# [68]	train-mae:0.09276	eval-mae:0.09424
# [69]	train-mae:0.09261	eval-mae:0.09411
# [70]	train-mae:0.09241	eval-mae:0.09392
# [71]	train-mae:0.09231	eval-mae:0.09386
# [72]	train-mae:0.09228	eval-mae:0.09384
# [73]	train-mae:0.09217	eval-mae:0.09377
# [74]	train-mae:0.09187	eval-mae:0.09348
# [75]	train-mae:0.09180	eval-mae:0.09342
# [76]	train-mae:0.09172	eval-mae:0.09335
# [77]	train-mae:0.09154	eval-mae:0.09317
# [78]	train-mae:0.09126	eval-mae:0.09292
# [79]	train-mae:0.09111	eval-mae:0.09278
# [80]	train-mae:0.09105	eval-mae:0.09274
# [81]	train-mae:0.09098	eval-mae:0.09270
# [82]	train-mae:0.09078	eval-mae:0.09252
# [83]	train-mae:0.09068	eval-mae:0.09244
# [84]	train-mae:0.09061	eval-mae:0.09237
# [85]	train-mae:0.09053	eval-mae:0.09232
# [86]	train-mae:0.09049	eval-mae:0.09229
# [87]	train-mae:0.09028	eval-mae:0.09210
# [88]	train-mae:0.09003	eval-mae:0.09186
# [89]	train-mae:0.08997	eval-mae:0.09181
# [90]	train-mae:0.08993	eval-mae:0.09178
# [91]	train-mae:0.08989	eval-mae:0.09176
# [92]	train-mae:0.08985	eval-mae:0.09173
# [93]	train-mae:0.08970	eval-mae:0.09159
# [94]	train-mae:0.08951	eval-mae:0.09142
# [95]	train-mae:0.08949	eval-mae:0.09140
# [96]	train-mae:0.08942	eval-mae:0.09135
# [97]	train-mae:0.08916	eval-mae:0.09110
# [98]	train-mae:0.08908	eval-mae:0.09104
# [99]	train-mae:0.08900	eval-mae:0.09098

# %%
predict_data = xgb.DMatrix(test_df)
y_pred = gbm.predict(predict_data)

# %%
columns = sample_submission.columns
columns
# Out:
# Index(['ID', '取引価格（総額）_log'], dtype='object')

# %%
for y in y_pred:
    sample_submission[columns[1]] = y
